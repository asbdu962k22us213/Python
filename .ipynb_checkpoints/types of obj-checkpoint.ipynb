# %%
a=1
print(type(a))
a='1'
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>

# %%
b=-10
c=10+20
print(b,c,b)
# Out:
# -10 30 -10

# %%
x=5.0
print(type(x))
y=5.553
print(type(y))
# Out:
# <class 'float'>
# <class 'float'>

# %%
#string
name='ravi'
print(type(name))
name="ravi"
print(type(name))
# Out:
# <class 'str'>
# <class 'str'>

# %%
name='ravi"      
#do not use this type it will gave you a error.
print(name)
# Out:
#   Cell In[8], line 1
#     name='ravi"
#          ^
# SyntaxError: unterminated string literal (detected at line 1)
