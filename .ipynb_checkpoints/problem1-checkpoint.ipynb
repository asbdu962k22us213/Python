# %%
w=int(input())
if(w%2==0 and w!=2):
    print("yes")
else:
    print("no")
# Out:
#  8
# yes

# %%
a=int(input())
b=int(input())
if((a*b)%2==0):
    print("even")
else:
    print("odd")
# Out:
#  3
#  4
# even
