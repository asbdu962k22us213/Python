# %%
n=4578
count=0
while(n!=0):
    n=n//10
    count+=1
print(count)
# Out:
# 5

# %%
n=54526
count=0
while(n!=0):
    n=n//10
    count+=1
if(count%2!=0):
    print("odd length")
elif (count%2==0):
    print("even length")
# Out:
# odd length

# %%
n=5452
sum=0
while(n!=0):
    d=n%10
    sum=sum+d
    n=n//10
print(sum)
# Out:
# 16

# %%
n=75428
pos=1
o_sum=0
while(n!=0):
    d=n%10
    if pos%2!=0:
        o_sum=o_sum+d
    n=n//10
    pos=pos+1
print(o_sum)
# Out:
# 19

# %%
n=5723648
count=0
while(n!=0):
    n=n//10
    count+=1
print(count)
if(count%2==0):
    print("even")
elif count%2!=0:
    print("odd")
# Out:
# 7
# odd

# %%
n=57236
o_sum=0
e_sum=0
while(n>0):
    d=n%10
    if d%2==0:
        e_sum=e_sum+d
        n=n//10
        print(f"sum of even is: {e_sum}")
    elif d%2!=0:
        o_sum=o_sum+d
        n=n//10
        print(f"sum of odd is: {o_sum}")
# Out:
# sum of even is: 6
# sum of odd is: 3
# sum of even is: 8
# sum of odd is: 10
# sum of odd is: 15

# %%
n=3584
while(n<0):
    d=n%10
print(d)
# Out:
# 4

# %%
n=3584
while(n>9):
    n=n//10
print(n)
# Out:
# 3

# %%
n=1890
max=0
temp=n
while(temp>0):
    d=temp%10
    if d>max:
        max=d
    temp//=10
print(max)
# Out:
# 9

# %%
n=1243
rev=0
temp=n
while(temp>0):
    d=temp%10
    rev=rev*10+d
    temp//=10
print(rev)
# Out:
# 3421

# %%
n=1890
min=9
temp=n
while(temp>0):
    d=temp%10
    if d<min:
        min=d
    temp//=10
print(min)
# Out:
# 0

# %%
n=8654
root=n
while root>=10:
    temp=root
    sum=0
    while(temp>0):
        sum+=temp%10
        temp//=10
        root=sum
print(root)
# Out:
# 5

# %%
n=486
temp=n
divi=True
while(temp>0):
    d=temp%10
    if(d==0 or n%d!=0):
        divi=False
        break
    temp//=10
print(divi)
# Out:
# False

# %%
n=486
k=2
count=0
temp=n
while(temp>0):
    d=temp%10
    if(d!=0 or d%k==0):
        count+=1
        temp//=10
print(count)
# Out:
# 3

# %%
n=121
f_digit=n
rev=0
temp=n
while(temp>0):
    d=temp%10
    rev=rev*10+d
    temp//=10
    palindrome=rev==f_digit
print("palindrome")
# Out:
# palindrome

# %%
n=482448
f_digit=n
rev=0
temp=n
while(temp>0):
    d=temp%10
    rev=rev*10+d
    temp//=10
    palindrome=rev!=f_digit
print("not palindrome")
# Out:
# not palindrome

# %%
n=1890
max_val=0
temp=n
while(temp>0):
    d=temp%10
    max_val=max_val*10+d
    temp//=10
if n%10==0:
    max_val=max_val*10
print(max_val)
# Out:
# 9810
