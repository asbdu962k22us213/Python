# %%
cm=int(input("Enter a height in cm:"))
inches=2.54*cm
feet=3.60*cm
print("the length in inches",round(inches,2))
print("the length in feet",round(feet,2))
# Out:
# Enter a height in cm: 50
# the length in inches 127.0
# the length in feet 180.0
