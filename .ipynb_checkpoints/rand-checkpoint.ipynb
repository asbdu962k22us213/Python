# %%
import random
rand_int=random.rand(1,100)
print(next(rand_int))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 import random
# ----> 2 rand_int=rand.rand(1,100)
#       3 print(next(rand_int))
#
# NameError: name 'rand' is not defined
