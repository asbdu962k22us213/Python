# %%
tamil = float(input("Enter a tamil mark:"))
eng = float(input("Enter a eng mark:"))
maths = float(input("Enter a maths mark:"))
total_sum = tamil + eng + maths
print(total_sum)
average = total_sum / 3
print('The average of three number is=',average)
# Out:
# Enter a tamil mark: 80
# Enter a eng mark: 78
# Enter a maths mark: 66
# 224.0
# The average of three number is= 74.66666666666667
