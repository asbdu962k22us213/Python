# %%
a=int(input("enter a value of a is:"))
sq=a*a
print("square of",a,"is",sq)
# Out:
# enter a value of a is: 4
# square of 4 is 16

# %%
import math
a=int(input("enter a value of a is:"))
sqrt=math.sqrt(a)
print(sqrt)
# Out:
# enter a value of a is: 25
# 5.0
