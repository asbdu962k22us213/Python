# %%
rollno=int(input("Enter your rollno:"))
name=input("Enter your name is:")
tamil=int(input("Enter your tamil mark:"))
eng=int(input("Enter your eng mark:"))
maths=int(input("Enter your maths mark:"))
total_mark=tamil+eng+maths
print('your total mark is=',total_mark)
average=total_mark/3
print('your average is=',average)
# Out:
# Enter your rollno: 8876
# Enter your name is: nandhini
# Enter your tamil mark: 70
# Enter your eng mark: 60
# Enter your maths mark: 66
# your total mark is= 196
# your average is= 65.33333333333333
