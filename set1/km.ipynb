# %%
km=float(input("enter a value of km is:"))
miles=km*0.621371
print('miles=',miles)
# Out:
# enter a value of km is: 44.2
# miles= 27.4645982

# %%
miles=float(input("enter a value of miles:"))
km=miles*1.60934
print('km=',km)
# Out:
# enter a value of miles: 33.5
# km= 53.91289
