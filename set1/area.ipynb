# %%
b=float(input("enter a value of b is:"))
h=float (input("enter a value of h is:"))
area=1/2*b*h
print(area)
# Out:
# enter a value of b is: 16.5
# enter a value of h is: 18.9
# 155.92499999999998
