# %%
Height=float(input("Enter a height in meter:"))
Weight=float(input("Enter a weight in km:"))
BMI=Weight/Height*Height
print('BMI is=',BMI)
# Out:
# Enter a height in meter: 36.8
# Enter a weight in km: 50.8
# BMI is= 50.800000000000004
